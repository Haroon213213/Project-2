# %% [markdown]
# <center><h2> Data Analysis

# %% [markdown]
# #### Import Required Python Packages

# %%
import pandas as pd
import numpy as np
import wbgapi as wb
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# #### Read data using wbgapi API

# %%
country_codes = ["LTU","LUX", 'LVA', 'BRA', 'MAF', 'BDI', 'BFA', 'CAF', 'BEN', 'BLZ'] 


### We have selected 5 high income and 5 low income countries from world bank website
country_names = {"LTU": 'Lithuania', 
                 "LUX": 'Luxembourg', 
                 "LVA": 'Latvia', 
                 "BRA": 'Brazil', 
                 "MAF": 'Saint Martin', 
                 "BDI": 'Burundi',
                 "BFA": 'Burkina Faso', 
                 "CAF": 'Central African Republic',
                 "BEN": 'Benin', 
                 "BLZ": 'Belize'}

indicator_ids = ["AG.LND.ARBL.ZS", "AG.LND.FRST.ZS"]

# %%
df  = wb.data.DataFrame(indicator_ids, country_codes, mrv=30) # most recent 10 years
df.reset_index(inplace = True)
df
# Out:
#    economy          series     YR1991     YR1992     YR1993     YR1994  \
# 0      BDI  AG.LND.ARBL.ZS  36.214953  36.214953  36.214953  36.214953
# 1      BDI  AG.LND.FRST.ZS  10.444938  10.123520   9.802103   9.480685
# 2      BEN  AG.LND.ARBL.ZS  14.366797  14.455481  14.632849  15.076268
# 3      BEN  AG.LND.FRST.ZS  42.259223  41.638436  41.017648  40.396861
# 4      BFA  AG.LND.ARBL.ZS  12.719298  12.627924  12.536550  12.284357
# 5      BFA  AG.LND.FRST.ZS  28.021162  27.838377  27.655592  27.472807
# 6      BLZ  AG.LND.ARBL.ZS   2.367383   2.455064   2.630425   2.630425
# 7      BLZ  AG.LND.FRST.ZS  69.529022  68.912056  68.295090  67.678124
# 8      BRA  AG.LND.ARBL.ZS   5.530656   5.397493   5.264210   5.131046
# 9      BRA  AG.LND.FRST.ZS  70.005654  69.553288  69.100922  68.648556
# 10     CAF  AG.LND.ARBL.ZS   3.081961   3.098013   3.098013   3.098013
# 11     CAF  AG.LND.FRST.ZS  37.197021  37.148865  37.100709  37.052554
# 12     LTU  AG.LND.ARBL.ZS        NaN  46.027441  45.118060  41.320996
# 13     LTU  AG.LND.FRST.ZS  31.030632  31.269943  31.389598  31.509253
# 14     LUX  AG.LND.ARBL.ZS        NaN        NaN        NaN        NaN
# 15     LUX  AG.LND.FRST.ZS        NaN        NaN        NaN        NaN
# 16     LVA  AG.LND.ARBL.ZS        NaN  27.140009  27.123931  27.493730
# 17     LVA  AG.LND.FRST.ZS  51.016143  51.234806  51.344138  51.453470
# 18     MAF  AG.LND.ARBL.ZS        NaN        NaN        NaN        NaN
# 19     MAF  AG.LND.FRST.ZS  18.382353  18.382353  18.382353  18.382353
#
#        YR1995     YR1996     YR1997     YR1998  ...     YR2011     YR2012  \
# 0   36.604361  36.604361  36.993769  36.993769  ...  38.940810  42.834891
# 5   22.903509  22.720760
# 6         NaN        NaN
# 7   56.475669  55.986409
# 8         NaN        NaN
# 9   59.558526  59.417478
# 10        NaN        NaN
# 11  35.848663  35.800507
# 12        NaN        NaN
# 13  35.126936  35.142903
# 14        NaN        NaN
# 15  36.502058  36.502058
# 16        NaN        NaN
# 17  54.870672  54.933000
# 18        NaN        NaN
# 19  24.800000  24.800000
#
# [20 rows x 32 columns]

# %%
def data_preprocessing(data):
    
    """
    This code will do all the required pro-processing in  data to get it into the format
    that is required to perform analysis. We need Year and country names as columns.
    This function will make use of pivot table as well.
    """
    data.replace(['AG.LND.ARBL.ZS', 'AG.LND.FRST.ZS'], ['Forest land', "Arable land"], inplace = True)
    data.rename(columns = {'economy':'Country', 'series':'Land'}, inplace = True)
    data['Country'] = data['Country'].map(country_names)
    data =pd.pivot_table(data,index=["Country"],values=['YR1991', 'YR1992', 'YR1993', 'YR1994', 'YR1995',
       'YR1996', 'YR1997', 'YR1998', 'YR1999', 'YR2000', 'YR2001', 'YR2002',
       'YR2003', 'YR2004', 'YR2005', 'YR2006', 'YR2007', 'YR2008', 'YR2009',
       'YR2010', 'YR2011', 'YR2012', 'YR2013', 'YR2014', 'YR2015', 'YR2016',
       'YR2017', 'YR2018', 'YR2019', 'YR2020'], columns = ['Land'])
    data = data.T.reset_index()
    data = data.rename(columns = {'level_0':'Year'})
    data['Year'] = data['Year'].str.replace('YR', '')
    data["Year"] = data['Year'].astype(int)
    return data

df = data_preprocessing(df)
df.head()
# Out:
# Country  Year         Land     Belize      Benin     Brazil  Burkina Faso  \
# 0        1991  Arable land  69.529022  42.259223  70.005654     28.021162
# 1        1991  Forest land   2.367383  14.366797   5.530656     12.719298
# 2        1992  Arable land  68.912056  41.638436  69.553288     27.838377
# 3        1992  Forest land   2.455064  14.455481   5.397493     12.627924
# 4        1993  Arable land  68.295090  41.017648  69.100922     27.655592
#
# Country    Burundi  Central African Republic     Latvia  Lithuania  \
# 0        10.444938                 37.197021  51.016143  31.030632
# 1        36.214953                  3.081961        NaN        NaN
# 2        10.123520                 37.148865  51.234806  31.269943
# 3        36.214953                  3.098013  27.140009  46.027441
# 4         9.802103                 37.100709  51.344138  31.389598
#
# Country  Luxembourg  Saint Martin
# 0               NaN     18.382353
# 1               NaN           NaN
# 2               NaN     18.382353
# 3               NaN           NaN
# 4               NaN     18.382353

# %%
# Pandas describe function to get statistical insights of numerical data.

# For Arable Land
df.loc[df['Land'] == "Arable land"].describe().T.style.background_gradient(cmap='Set2',low =0.4,high=0.1,axis=0)
# Out:
# <style type="text/css">
# #T_8ea69_row0_col0, #T_8ea69_row0_col1, #T_8ea69_row0_col2, #T_8ea69_row0_col3, #T_8ea69_row0_col4, #T_8ea69_row0_col5, #T_8ea69_row0_col6, #T_8ea69_row0_col7, #T_8ea69_row1_col0, #T_8ea69_row2_col0, #T_8ea69_row3_col0, #T_8ea69_row4_col0, #T_8ea69_row5_col0, #T_8ea69_row6_col0, #T_8ea69_row7_col0, #T_8ea69_row8_col0, #T_8ea69_row10_col0 {
#   background-color: #b3b3b3;
#   color: #000000;
# }
# #T_8ea69_row1_col1, #T_8ea69_row1_col3, #T_8ea69_row1_col4, #T_8ea69_row1_col5, #T_8ea69_row1_col6, #T_8ea69_row1_col7, #T_8ea69_row2_col1, #T_8ea69_row2_col3, #T_8ea69_row2_col4, #T_8ea69_row2_col5, #T_8ea69_row2_col6, #T_8ea69_row2_col7, #T_8ea69_row3_col1, #T_8ea69_row3_col3, #T_8ea69_row3_col4, #T_8ea69_row3_col5, #T_8ea69_row3_col6, #T_8ea69_row3_col7, #T_8ea69_row4_col1, #T_8ea69_row4_col2, #T_8ea69_row4_col3, #T_8ea69_row4_col4, #T_8ea69_row4_col5, #T_8ea69_row4_col6, #T_8ea69_row4_col7, #T_8ea69_row5_col1, #T_8ea69_row5_col2, #T_8ea69_row5_col3, #T_8ea69_row5_col4, #T_8ea69_row5_col5, #T_8ea69_row5_col6, #T_8ea69_row5_col7, #T_8ea69_row6_col1, #T_8ea69_row6_col2, #T_8ea69_row6_col3, #T_8ea69_row6_col4, #T_8ea69_row6_col5, #T_8ea69_row6_col6, #T_8ea69_row6_col7, #T_8ea69_row7_col1, #T_8ea69_row7_col2, #T_8ea69_row7_col3, #T_8ea69_row7_col4, #T_8ea69_row7_col5, #T_8ea69_row7_col6, #T_8ea69_row7_col7, #T_8ea69_row8_col1, #T_8ea69_row8_col2, #T_8ea69_row8_col3, #T_8ea69_row8_col4, #T_8ea69_row8_col5, #T_8ea69_row8_col6, #T_8ea69_row8_col7, #T_8ea69_row9_col0, #T_8ea69_row9_col1, #T_8ea69_row9_col2, #T_8ea69_row9_col3, #T_8ea69_row9_col4, #T_8ea69_row9_col5, #T_8ea69_row9_col6, #T_8ea69_row9_col7, #T_8ea69_row10_col1, #T_8ea69_row10_col3, #T_8ea69_row10_col4, #T_8ea69_row10_col5, #T_8ea69_row10_col6, #T_8ea69_row10_col7 {
#   background-color: #8da0cb;
#   color: #f1f1f1;
# }
# #T_8ea69_row1_col2, #T_8ea69_row2_col2, #T_8ea69_row3_col2 {
#   background-color: #a6d854;
#   color: #000000;
# }
# #T_8ea69_row10_col2 {
#   background-color: #e78ac3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8ea69_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_
#       <td id="T_8ea69_row4_col3" class="data row4 col3" >22.720760</td>
#       <td id="T_8ea69_row4_col4" class="data row4 col4" >24.045852</td>
#       <td id="T_8ea69_row4_col5" class="data row4 col5" >25.370980</td>
#       <td id="T_8ea69_row4_col6" class="data row4 col6" >26.695970</td>
#       <td id="T_8ea69_row4_col7" class="data row4 col7" >28.021162</td>
#     </tr>
#     <tr>
#       <th id="T_8ea69_level0_row5" class="row_heading level0 row5" >Burundi</th>
#       <td id="T_8ea69_row5_col0" class="data row5 col0" >30.000000</td>
#       <td id="T_8ea69_row5_col1" class="data row5 col1" >8.924234</td>
#       <td id="T_8ea69_row5_col2" class="data row5 col2" >1.353848</td>
#       <td id="T_8ea69_row5_col3" class="data row5 col3" >7.552181</td>
#       <td id="T_8ea69_row5_col4" class="data row5 col4" >7.552181</td>
#       <td id="T_8ea69_row5_col5" class="data row5 col5" >8.677142</td>
#       <td id="T_8ea69_row5_col6" class="data row5 col6" >10.197352</td>
#       <td id="T_8ea69_row5_col7" class="data row5 col7" >10.889408</td>
#     </tr>
#     <tr>
#       <th id="T_8ea69_level0_row6" class="row_heading level0 row6" >Central African Republic</th>
#       <td id="T_8ea69_row6_col0" class="data row6 col0" >30.000000</td>
#       <td id="T_8ea69_row6_col1" class="data row6 col1" >36.498764</td>
#       <td id="T_8ea69_row6_col2" class="data row6 col2" >0.423934</td>
#       <td id="T_8ea69_row6_col3" class="data row6 col3" >35.800507</td>
#       <td id="T_8ea69_row6_col4" class="data row6 col4" >36.149636</td>
#       <td id="T_8ea69_row6_col5" class="data row6 col5" >36.498764</td>
#       <td id="T_8ea69_row6_col6" class="data row6 col6" >36.847892</td>
#       <td id="T_8ea69_row6_col7" class="data row6 col7" >37.197021</td>
#     </tr>
#     <tr>
#       <th id="T_8ea69_level0_row7" class="row_heading level0 row7" >Latvia</th>
#       <td id="T_8ea69_row7_col0" class="data row7 col0" >30.000000</td>
#       <td id="T_8ea69_row7_col1" class="data row7 col1" >53.162365</td>
#       <td id="T_8ea69_row7_col2" class="data row7 col2" >1.320429</td>
#       <

# %%
## For forest lands
df.loc[df['Land'] == "Forest land"].describe().T.style.background_gradient(cmap='Set2',low =0.4,high=0.1,axis=0)
# Out:
# <style type="text/css">
# #T_425be_row0_col0, #T_425be_row0_col1, #T_425be_row0_col2, #T_425be_row0_col3, #T_425be_row0_col4, #T_425be_row0_col5, #T_425be_row0_col6, #T_425be_row0_col7, #T_425be_row1_col0, #T_425be_row2_col0, #T_425be_row3_col0, #T_425be_row4_col0, #T_425be_row5_col0, #T_425be_row6_col0, #T_425be_row7_col0, #T_425be_row8_col0 {
#   background-color: #b3b3b3;
#   color: #000000;
# }
# #T_425be_row1_col1, #T_425be_row1_col2, #T_425be_row1_col3, #T_425be_row1_col4, #T_425be_row1_col5, #T_425be_row1_col6, #T_425be_row1_col7, #T_425be_row2_col1, #T_425be_row2_col3, #T_425be_row2_col4, #T_425be_row2_col5, #T_425be_row2_col6, #T_425be_row2_col7, #T_425be_row3_col1, #T_425be_row3_col2, #T_425be_row3_col3, #T_425be_row3_col4, #T_425be_row3_col5, #T_425be_row3_col6, #T_425be_row3_col7, #T_425be_row4_col1, #T_425be_row4_col3, #T_425be_row4_col4, #T_425be_row4_col5, #T_425be_row4_col6, #T_425be_row4_col7, #T_425be_row5_col1, #T_425be_row5_col3, #T_425be_row5_col4, #T_425be_row5_col5, #T_425be_row5_col6, #T_425be_row5_col7, #T_425be_row6_col1, #T_425be_row6_col2, #T_425be_row6_col3, #T_425be_row6_col4, #T_425be_row6_col5, #T_425be_row6_col6, #T_425be_row6_col7, #T_425be_row7_col1, #T_425be_row7_col3, #T_425be_row7_col4, #T_425be_row7_col5, #T_425be_row7_col6, #T_425be_row7_col7, #T_425be_row8_col1, #T_425be_row8_col3, #T_425be_row8_col4, #T_425be_row8_col5, #T_425be_row8_col6, #T_425be_row8_col7, #T_425be_row9_col1, #T_425be_row9_col2, #T_425be_row9_col3, #T_425be_row9_col4, #T_425be_row9_col5, #T_425be_row9_col6, #T_425be_row9_col7, #T_425be_row10_col0 {
#   background-color: #8da0cb;
#   color: #f1f1f1;
# }
# #T_425be_row2_col2, #T_425be_row4_col2, #T_425be_row5_col2, #T_425be_row7_col2 {
#   background-color: #a6d854;
#   color: #000000;
# }
# #T_425be_row8_col2 {
#   background-color: #e5c494;
#   color: #000000;
# }
# #T_425be_row9_col0 {
#   background-color: #ffd92f;
#   color: #000000;
# }
# #T_425be_row10_col1, #T_425be_row10_col2, #T_425be_row10_col3, #T_425be_row10_col4, #T_425be_row10_col5, #T_425be_row10_col6, #T_425be_row10_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_425be_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_425be_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_425be_row0_col0" class="data row0 col0" >28.000000</td>
#       <td id="T_425be_row0_col1" class="data row0 col1" >2004.500000</td>
#       <td id="T_425be_row0_col2" class="data row0 col2" >8.225975</td>
#       <td id="T_425be_row0_col3" class="data row0 col3" >1991.000000</td>
#       <td id="T_425be_row0_col4" class="data row0 col4" >1997.750000</td>
#       <td id="T_425be_row0_col5" class="data row0 col5" >2004.500000</td>
#       <td id="T_425be_row0_col6" class="data row0 col6" >2011.250000</td>
#       <td id="T_425be_row0_col7" class="data row0 col7" >2018.000000</td>
#     </tr>
#     <tr>
#       <th id="T_425be_level0_row1" class="row_heading level0 row1" >Belize</th>
#       <td id="T_425be_row1_col0" class="data row1 col0" >28.000000</td>
#       <td id="T_425be_row1_col1" class="data row1 col1" >3.098578</td>
#       <td id="T_425be_row1_col2" class="data row1 col2" >0.431869</td>
#       <td id="T_425be_row1_col3" class="data row1 col3" >2.367383</td>
#       <td id="T_425be_row1_col4" class="data row1 col4" >2.805787</td>
#       <td id="T_425be_row1_col5" class="data row1 col5" >3.068829</td>
#       <td id="T_425be_row1_col6" class="data row1 col6" >3.320912</td>
#       <td id="T_425be_row1_col7" class="data row1 col7" >3.945638</td>
#     </tr>
#     <tr>
#       <th id="T_425be_level0_row2" class="row_heading level0 row2" >Benin</th>
#       <td id="T_425be_row2_col0" class="data row2 col0" >28.000000</td>
#       <td id="T_425be_row2_col1" class="data row2 col1" >21.038362</td>
#       <td id="T_425be_row2_col2" class="data row2 col2" >3.411017</td>
#       <td id="T_425be_row2_col3" class="data row2 col3" >14.366797</td>
#       <td id="T_425be_row2_col4" class="data row2 col4" >19.621320</td>
#       <td id="T_425be_row2_col5" class="data row2 col5" >22.170983</td>
#       <td id="T_425be_row2_col6" class="data row2 col6" >23.510110</td>
#       <td id="T_425be_row2_col7" class="data row2 col7" >24.831501</td>
#     </tr>
#     <tr>
#       <th id="T_425be_level0_row3" class="row_heading level0 row3" >Brazil</th>
#       <td id="T_425be_row3_col0" class="data row3 col0" >28.000000</td>
#       <td id="T_425be_row3_col1" class="data row3 col1" >5.819712</td>
#       <td id="T_425be_row3_col2" class="data row3 col2" >0.510680</td>
#       <td id="T_425be_row3_col3" class="data row3 col3" >5.092401</td>
#       <td id="T_425be_row3_col4" class="data row3 col4" >5.390254</td>
#       <td id="T_425be_row3_col5" class="data row3 col5" >5.748229</td>
#       <td id="T_425be_row3_col6" class="data row3 col6" >6.243345</td>
#       <td id="T_425be_row3_col7" class="data row3 col7" >6.671580</td>
#     </tr>
#     <tr>
#       <th id="T_425be_level0_row4" class="row_heading level0 row4" >Burkina Faso</th>
#       <td id="T_425be_row4_col0" class="data row4 col0" >28.000000</td>
#       <td id="T_425be_row4_col1" class="data row4 col1" >17.604689</td>
#       <td id="T_425be_row4_col2" class="data row4 col2" >3.883408</td>
#       <td id="T_425be_row4_col3" class="data row4 col3" >12.284357</td>
#       <td id="T_425be_row4_col4" class="data row4 col4" >13.742690</td>
#       <td id="T_425be_row4_col5" class="data row4 col5" >17.543860</td>
#       <td id="T_425be_row4_col6" class="data row4 col6" >21.929825</td>
#       <td id="T_425be_row4_col7" class="data row4 col7" >22.660819</td>
#     </tr>
#     <tr>
#       <th id="T_425be_level0_row5" class="row_heading level0 row5" >Burundi</th>
#       <td id="T_425be_row5_col0" class="data row5 col0" >28.000000</td>
#       <td id="T_425be_row5_col1" class="data row5 col1" >39.166110</td>
#       <td id="T_425be_row5_col2" class="data row5 col2" >4.335259</td>
#       <td id="T_425be_row5_col3" class="data row5 col3" >33.099688</td>
#       <td id="T_425be_row5_col4" class="data row5 col4" >36.507009</td>
#       <td id="T_425be_row5_col5" class="data row5 col5" >37.305296</td>
#       <td id="T_425be_row5_col6" class="data row5 col6" >39.914330</td>
#       <td id="T_425be_row5_col7" class="data row5 col7" >46.728972</td>
#     </tr>
#     <tr>
#       <th id="T_425be_level0_row6" class="row_heading level0 row6" >Central African Republic</th>
#       <td id="T_425be_row6_col0" class="data row6 col0" >28.000000</td>
#       <td id="T_425be_row6_col1" class="data row6 col1" >3.030366</td>
#       <td id="T_425be_row6_col2" class="data row6 col2" >0.099274</td>
#       <td id="T_425be_row6_col3" class="data row6 col3" >2.889338</td>
#       <td id="T_425be_row6_col4" class="data row6 col4" >2.889338</td>
#       <td id="T_425be_row6_col5" class="data row6 col5" >3.098013</td>
#       <td id="T_425be_row6_col6" class="data row6 col6" >3.098013</td>
#       <td id="T_425be_row6_col7" class="data row6 col7" >3.130117</td>
#     </tr>
#     <tr>
#       <th id="T_425be_level0_row7" class="row_heading level0 row7" >Latvia</th>
#       <td id="T_425be_row7_col0" class="data row7 col0" >27.000000</td>
#       <td id="T_425be_row7_col1" class="data row7 col1" >19.0548

# %% [markdown]
# __Inference:__  The table above depicts various statistical measures of forest and arable land area in high- and low-income countries. Forests cover a large portion of the land in high-income countries like Latvia, Lithuania, and Luxembourg.

# %%
## Because bar plot are suitable to compare and visualize continusous numerical and cateogrical features
def barplot(x, y):
    
    """"
    Developing bar plots to compare the Forest and Arable Land percentage in 
    High income and low income countries
    """
    plt.figure(figsize=(20, 20))

    for e, column in enumerate(y):
        plt.subplot(4, 3, e + 1)
        sns.barplot(x=x ,y=column, data=df)
        plt.ylabel(column,fontsize=14)
        
## Develop graph for 3 high income countries    
barplot('Land', ['Lithuania', 'Luxembourg', 'Latvia'])

# %%
## use same above function for Low income countries

barplot('Land', ['Belize', 'Benin', 'Burundi'])

# %% [markdown]
# __Inference:__ We can observe from the above plot that Lithuania has more forest land (more than 30%) as compared to arable land. Low-income countries' land records, on the other hand, clearly indicate how their governments have mismanaged their lands. Belize uses 60% of its land for agriculture and has less than 5% of its area for forest.

# %%
## Because scatter plot are suitable to compare and visualize two numerical features, we'll use it's hie functio as well to 
## differentiate between two different categories and get data for each in different color.

def scatterplot(x, y):
    
    """"
    Developing scatterplots to compare the development or decline in forest land over time
    in High and low income countries.
    """

    plt.figure(figsize=(20, 20))

    for e, column in enumerate(y):
        plt.subplot(4, 3, e + 1)
        sns.scatterplot(data=df, x=x, y=column, hue="Land")
        plt.xticks(rotation = 45,fontsize=14)
        plt.ylabel(column,fontsize=14)

## Develop scatterplot for 3 high income countries    
scatterplot("Year", ['Lithuania', 'Luxembourg', 'Latvia'])

# %%
## use same above function for Low income countries
scatterplot("Year", ['Belize', 'Benin', 'Burundi'])

# %% [markdown]
# __Inference:__ The graph above indicates that forest land in three of our high-income countries has been steadily increasing over time. While we can observe from that Low income countries have continual decline in their Forest land over time.

# %% [markdown]
# <Center><h2> THE END
